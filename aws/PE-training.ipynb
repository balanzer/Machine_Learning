# %% [markdown]
# # Practice Exercise – Model Training and Evaluation

# %% [markdown]
# # Problem 1: Spam email classification
#
# In this example, you will work on classifying emails as spam or not spam.
#
# You will use the [Spambase Data Set](https://archive.ics.uci.edu/ml/datasets/Spambase) from the University of California, Irvine (UCI) Machine Learning Repository.
#
# __Source information:__
#
# Creators:
# Mark Hopkins, Erik Reeber, George Forman, Jaap Suermondt, Hewlett-Packard Labs, 1501 Page Mill Rd., Palo Alto, CA 94304
#
# Donor:
# George Forman gforman@hpl.hp.com 650-857-7835
#
# ----------------------------------------------------------------------------
#
# The data has 57 attributes and 1 target. They are described below.
# - 48 continuous real [0,100] attributes of type word_freq_WORD
# = percentage of words in the e-mail that match WORD,
# i.e. 100 * (number of times the WORD appears in the e-mail) /
# total number of words in e-mail.  A "word" in this case is any
# string of alphanumeric characters bounded by non-alphanumeric
# characters or end-of-string.
#
# - 6 continuous real [0,100] attributes of type char_freq_CHAR
# = percentage of characters in the e-mail that match CHAR,
# i.e. 100 * (number of CHAR occurrences) / total characters in e-mail
#
# - 1 continuous real [1,...] attribute of type capital_run_length_average
# = average length of uninterrupted sequences of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_longest
# = length of longest uninterrupted sequence of capital letters
#
# - 1 continuous integer [1,...] attribute of type capital_run_length_total
# = sum of length of uninterrupted sequences of capital letters
# = total number of capital letters in the e-mail
#
# - 1 nominal {0,1} class attribute of type spam
# = denotes whether the e-mail was considered spam (1) or not (0), i.e. unsolicited commercial e-mail.

# %% [markdown]
# ## 1. Getting the data

# %%
import subprocess
import os

# Check whether the file is already in the desired path or if it needs to be downloaded
# File downloaded from source : https://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.data

base_path = '/home/ec2-user/SageMaker/data/'
file_path = 'spambase.data'

if not os.path.isfile(base_path + file_path):
    subprocess.run(['mkdir', '-p', base_path])
    subprocess.run(['aws', 's3', 'cp', 
                    's3://aws-tc-largeobjects/ILT-TF-200-MLDWTS/lab3/', 
                    base_path,'--recursive'])
else:
    print('File already downloaded!')

# %%
import csv
import numpy as np

data = []

f = open('/home/ec2-user/SageMaker/data/spambase.data')
reader = csv.reader(f)
next(reader, None)
for row in reader:
    data.append(row)
f.close()

# %% [markdown]
# Write the data into a DataFrame for easier visualization and analysis. Also, add the attribute names, which are from the "spambase.names" file in the dataset package.

# %%
import pandas as pd

df = pd.DataFrame(data=np.array(data).astype(np.float), columns=["word_freq_make",
            "word_freq_address",
            "word_freq_all",
            "word_freq_3d",
            "word_freq_our",
            "word_freq_over",
            "word_freq_remove",
            "word_freq_internet",
            "word_freq_order",
            "word_freq_mail",
            "word_freq_receive",
            "word_freq_will",
            "word_freq_people",
            "word_freq_report",
            "word_freq_addresses",
            "word_freq_free",
            "word_freq_business",
            "word_freq_email",
            "word_freq_you",
            "word_freq_credit",
            "word_freq_your",
            "word_freq_font",
            "word_freq_000",
            "word_freq_money",
            "word_freq_hp",
            "word_freq_hpl",
            "word_freq_george",
            "word_freq_650",
            "word_freq_lab",
            "word_freq_labs",
            "word_freq_telnet",
            "word_freq_857",
            "word_freq_data",
            "word_freq_415",
            "word_freq_85",
            "word_freq_technology",
            "word_freq_1999",
            "word_freq_parts",
            "word_freq_pm",
            "word_freq_direct",
            "word_freq_cs",
            "word_freq_meeting",
            "word_freq_original",
            "word_freq_project",
            "word_freq_re",
            "word_freq_edu",
            "word_freq_table",
            "word_freq_conference",
            "char_freq_;",
            "char_freq_(",
            "char_freq_[",
            "char_freq_!",
            "char_freq_$",
            "char_freq_#",
            "capital_run_length_average",
            "capital_run_length_longest",
            "capital_run_length_total",
            "target"]
            )

# %% [markdown]
# Look at the shape of the data. There are 58 columns (including the target) as expected.

# %%
df.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.21               0.28           0.50           0.0
# 1            0.06               0.00           0.71           0.0
# 2            0.00               0.00           0.00           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.14            0.28              0.21                0.07
# 1           1.23            0.19              0.19                0.12
# 2           0.63            0.00              0.31                0.63
# 3           0.63            0.00              0.31                0.63
# 4           1.85            0.00              0.00                1.85
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.94  ...         0.00        0.132
# 1             0.64            0.25  ...         0.01        0.143
# 2             0.31            0.63  ...         0.00        0.137
# 3             0.31            0.63  ...         0.00        0.135
# 4             0.00            0.00  ...         0.00        0.223
#
#    char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# 0          0.0        0.372        0.180        0.048
# 1          0.0        0.276        0.184        0.010
# 2          0.0        0.137        0.000        0.000
# 3          0.0        0.135        0.000        0.000
# 4          0.0        0.000        0.000        0.000
#
#    capital_run_length_average  capital_run_length_longest  \
# 0                       5.114                       101.0
# 1                       9.821                       485.0
# 2                       3.537                        40.0
# 3                       3.537                        40.0
# 4                       3.000                        15.0
#
#    capital_run_length_total  target
# 0                    1028.0     1.0
# 1                    2259.0     1.0
# 2                     191.0     1.0
# 3                     191.0     1.0
# 4                      54.0     1.0
#
# [5 rows x 58 columns]

# %% [markdown]
# The `df.describe()` function presents a statistical summary of the features.

# %%
df.describe()
# Out:
#        word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# count     4600.000000        4600.000000    4600.000000   4600.000000
# mean         0.104576           0.212922       0.280578      0.065439
# std          0.305387           1.290700       0.504170      1.395303
# min          0.000000           0.000000       0.000000      0.000000
# 25%          0.000000           0.000000       0.000000      0.000000
# 50%          0.000000           0.000000       0.000000      0.000000
# 75%          0.000000           0.000000       0.420000      0.000000
# max          4.540000          14.280000       5.100000     42.810000
#
#        word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# count    4600.000000     4600.000000       4600.000000         4600.000000
# mean        0.312222        0.095922          0.114233            0.105317
# std         0.672586        0.273850          0.391480            0.401112
# min         0.000000        0.000000          0.000000            0.000000
# 25%         0.000000        0.000000          0.000000            0.000000
# 50%         0.000000        0.000000          0.000000            0.000000
# 75%         0.382500        0.000000          0.000000            0.000000
# max        10.000000        5.880000          7.270000           11.110000
#
#        word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# count      4600.000000     4600.000000  ...  4600.000000  4600.000000
# mean          0.090087        0.239465  ...     0.038583     0.139061
# std           0.278643        0.644816  ...     0.243497     0.270377
# min           0.000000        0.000000  ...     0.000000     0.000000
# 25%           0.000000        0.000000  ...     0.000000     0.000000
# 50%           0.000000        0.000000  ...     0.000000     0.065000
# 75%           0.000000        0.160000  ...     0.000000     0.188000
# max           5.260000       18.180000  ...     4.385000     9.752000
#
#        char_freq_[  char_freq_!  char_freq_$  char_freq_#  \
# count  4600.000000  4600.000000  4600.000000  4600.000000
# mean      0.016980     0.268960     0.075827     0.044248
# std       0.109406     0.815726     0.245906     0.429388
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.314250     0.052000     0.000000
# max       4.081000    32.478000     6.003000    19.829000
#
#        capital_run_length_average  capital_run_length_longest  \
# count                 4600.000000                 4600.000000
# mean                     5.191827                   52.170870
# std                     31.732891                  194.912453
# min                      1.000000                    1.000000
# 25%                      1.588000                    6.000000
# 50%                      2.275500                   15.000000
# 75%                      3.705250                   43.000000
# max                   1102.500000                 9989.000000
#
#        capital_run_length_total       target
# count               4600.000000  4600.000000
# mean                 283.290435     0.393913
# std                  606.413764     0.488669
# min                    1.000000     0.000000
# 25%                   35.000000     0.000000
# 50%                   95.000000     0.000000
# 75%                  265.250000     1.000000
# max                15841.000000     1.000000
#
# [8 rows x 58 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 58 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   word_freq_make              4600 non-null   float64
#  1   word_freq_address           4600 non-null   float64
#  2   word_freq_all               4600 non-null   float64
#  3   word_freq_3d                4600 non-null   float64
#  4   word_freq_our               4600 non-null   float64
#  5   word_freq_over              4600 non-null   float64
#  6   word_freq_remove            4600 non-null   float64
#  7   word_freq_internet          4600 non-null   float64
#  8   word_freq_order             4600 non-null   float64
#  9   word_freq_mail              4600 non-null   float64
#  10  word_freq_receive           4600 non-null   float64
#  11  word_freq_will              4600 non-null   float64
#  12  word_freq_people            4600 non-null   float64
#  13  word_freq_report            4600 non-null   float64
#  14  word_freq_addresses         4600 non-null   float64
#  15  word_freq_free              4600 non-null   float64
#  16  word_freq_business          4600 non-null   float64
#  17  word_freq_email             4600 non-null   float64
#  18  word_freq_you               4600 non-null   float64
#  19  word_freq_credit            4600 non-null   float64
#  20  word_freq_your              4600 non-null   float64
#  21  word_freq_font              4600 non-null   float64
#  22  word_freq_000               4600 non-null   float64
#  23  word_freq_money             4600 non-null   float64
#  24  word_freq_hp                4600 non-null   float64
#  25  word_freq_hpl               4600 non-null   float64
#  26  word_freq_george            4600 non-null   float64
#  27  word_freq_650               4600 non-null   float64
#  28  word_freq_lab               4600 non-null   float64
#  29  word_freq_labs              4600 non-null   float64
#  30  word_freq_telnet            4600 non-null   float64
#  31  word_freq_857               4600 non-null   float64
#  32  word_freq_data              4600 non-null   float64
#  33  word_freq_415               4600 non-null   float64
#  34  word_freq_85                4600 non-null   float64
#  35  word_freq_technology        4600 non-null   float64
#  36  word_freq_1999              4600 non-null   float64
#  37  word_freq_parts             4600 non-null   float64
#  38  word_freq_pm                4600 non-null   float64
#  39  word_freq_direct            4600 non-null   float64
#  40  word_freq_cs                4600 non-null   float64
#  41  word_freq_meeting           4600 non-null   float64
#  42  word_freq_original          4600 non-null   float64
#  43  word_freq_project           4600 non-null   float64
#  44  word_freq_re                4600 non-null   float64
#  45  word_freq_edu               4600 non-null   float64
#  46  word_freq_table             4600 non-null   float64
#  47  word_freq_conference        4600 non-null   float64
#  48  char_freq_;                 4600 non-null   float64
#  49  char_freq_(                 4600 non-null   float64
#  50  char_freq_[                 4600 non-null   float64
#  51  char_freq_!                 4600 non-null   float64
#  52  char_freq_$                 4600 non-null   float64
#  53  char_freq_#                 4600 non-null   float64
#  54  capital_run_length_average  4600 non-null   float64
#  55  capital_run_length_longest  4600 non-null   float64
#  56  capital_run_length_total    4600 non-null   float64
#  57  target                      4600 non-null   float64
# dtypes: float64(58)
# memory usage: 2.0 MB

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get the feature values until the target column (not included)
X = df.values[:, :-1].astype(np.float32)

# Get the target column
y = df.values[:, -1].astype(np.float32)

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (3680, 57)
# Length of train_labels is: (3680,)
# Length of val_features is: (460, 57)
# Length of val_labels is: (460,)
# Length of test_features is: (460, 57)
# Length of test_labels is: (460,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'binary_classifier'__ because there are two classes: "spam" and "not spam".

# %%
import sagemaker

# Call the LinearLearner estimator object
binary_estimator = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               instance_count=1,
                                               instance_type='ml.m4.xlarge',
                                               predictor_type='binary_classifier')

# %%
binary_estimator

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = binary_estimator.record_set(train_features, train_labels, channel='train')
val_records = binary_estimator.record_set(val_features, val_labels, channel='validation')
test_records = binary_estimator.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies a distributed version of the Stochastic Gradient Descent (SGD) algorithm, and we are sending the data to it.

# %%
binary_estimator.fit([train_records, val_records, test_records])
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-12-14 19:57:29 Starting - Starting the training job...
# 2021-12-14 19:57:53 Starting - Launching requested ML instancesProfilerReport-1639511849: InProgress
# ...
# 2021-12-14 19:58:20 Starting - Preparing the instances for training............
# 2021-12-14 20:00:13 Downloading - Downloading input data...
# 2021-12-14 20:00:57 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/14/2021 20:01:02 INFO 139845566875456] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/14/2021 20:01:02 INFO 139845566875456] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '57', 'predictor_type': 'binary_classifier', 'mini_batch_size': '1000'}
# [12/14/2021 20:01:02 INFO 139845566875456] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '57', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [12/14/2021 20:01:02 WARNING 139845566875456] Loggers have already been setup.
# Process 1 is a worker.
# [12/14/2021 20:01:02 INFO 139845566875456] Using default worker.
# [12/14/2021 20:01:03 INFO 139845566875456] Checkpoint loading and saving are disabled.
# [2021-12-14 20:01:03.020] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-12-14 20:01:03.022] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-12-14 20:01:03.041] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 24, "num_examples": 1, "num_bytes": 276000}
# [12/14/2021 20:01:03 INFO 139845566875456] Create Store: local
# [2021-12-14 20:01:03.084] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration":
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3196044921875, "count": 1, "min": 0.3196044921875, "max": 0.3196044921875}}}
# #metrics {"StartTime": 1639512063.756174, "EndTime": 1639512063.7561915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6513496730638587, "count": 1, "min": 0.6513496730638587, "max": 0.6513496730638587}}}
# #metrics {"StartTime": 1639512063.7562444, "EndTime": 1639512063.756261, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6620141070822011, "count": 1, "min": 0.6620141070822011, "max": 0.6620141070822011}}}
# #metrics {"StartTime": 1639512063.7563136, "EndTime": 1639512063.7563312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6297453507133152, "count": 1, "min": 0.6297453507133152, "max": 0.6297453507133152}}}
# #metrics {"StartTime": 1639512063.7563803, "EndTime": 1639512063.7563977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6380964196246603, "count": 1, "min": 0.6380964196246603, "max": 0.6380964196246603}}}
# #metrics {"StartTime": 1639512063.756458, "EndTime": 1639512063.7564766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.30591855256453804, "count": 1, "min": 0.30591855256453804, "max": 0.30591855256453804}}}
# #metrics {"StartTime": 1639512063.7565255, "EndTime": 1639512063.7565424, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3180979189665421, "count": 1, "min": 0.3180979189665421, "max": 0.3180979189665421}}}
# #metrics {"StartTime": 1639512063.7565954, "EndTime": 1639512063.7566116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.31239998858907947, "count": 1, "min": 0.31239998858907947, "max": 0.31239998858907947}}}
# #metrics {"StartTime": 1639512063.756664, "EndTime": 1639512063.7566814, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.31643756368885867, "count": 1, "min": 0.31643756368885867, "max": 0.31643756368885867}}}
# #metrics {"StartTime": 1639512063.7567356, "EndTime": 1639512063.756754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6014101111370584, "count": 1, "min": 0.6014101111370584, "max": 0.6014101111370584}}}
# #metrics {"StartTime": 1639512063.75681, "EndTime": 1639512063.7568262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6439681343410326, "count": 1, "min": 0.6439681343410326, "max": 0.6439681343410326}}}
# #metrics {"StartTime": 1639512063.7568657, "EndTime": 1639512063.7568817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6599726137907609, "count": 1, "min": 0.6599726137907609, "max": 0.6599726137907609}}}
# #metrics {"StartTime": 1639512063.756938, "EndTime": 1639512063.7569547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.707586669921875, "count": 1, "min": 0.707586669921875, "max": 0.707586669921875}}}
# #metrics {"StartTime": 1639512063.7570062, "EndTime": 1639512063.7570224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.41351033086362093, "count": 1, "min": 0.41351033086362093, "max": 0.41351033086362093}}}
# #metrics {"StartTime": 1639512063.7570746, "EndTime": 1639512063.75709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3938179016113281, "count": 1, "min": 0.3938179016113281, "max": 0.3938179016113281}}}
# #metrics {"StartTime": 1639512063.757133, "EndTime": 1639512063.7571497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.4258572454037874, "count": 1, "min": 0.4258572454037874, "max": 0.4258572454037874}}}
# #metrics {"StartTime": 1639512063.7572148, "EndTime": 1639512063.7572324, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3963949452275815, "count": 1, "min": 0.3963949452275815, "max": 0.3963949452275815}}}
# #metrics {"StartTime": 1639512063.7572925, "EndTime": 1639512063.7573102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.7097408128821332, "count": 1, "min": 0.7097408128821332, "max": 0.7097408128821332}}}
# #metrics {"StartTime": 1639512063.7573652, "EndTime": 1639512063.7573826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6855955704398777, "count": 1, "min": 0.6855955704398777, "max": 0.6855955704398777}}}
# #metrics {"StartTime": 1639512063.757448, "EndTime": 1639512063.7574663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6772880222486413, "count": 1, "min": 0.6772880222486413, "max": 0.6772880222486413}}}
# #metrics {"StartTime": 1639512063.7575314, "EndTime": 1639512063.75755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.
, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6315646565755209, "count": 1, "min": 0.6315646565755209, "max": 0.6315646565755209}}}
# #metrics {"StartTime": 1639512063.9056926, "EndTime": 1639512063.905704, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6003129679361979, "count": 1, "min": 0.6003129679361979, "max": 0.6003129679361979}}}
# #metrics {"StartTime": 1639512063.9057755, "EndTime": 1639512063.9057891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6133722330729167, "count": 1, "min": 0.6133722330729167, "max": 0.6133722330729167}}}
# #metrics {"StartTime": 1639512063.905831, "EndTime": 1639512063.905842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.28779421997070315, "count": 1, "min": 0.28779421997070315, "max": 0.28779421997070315}}}
# #metrics {"StartTime": 1639512063.9058814, "EndTime": 1639512063.9058921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.2840665384928385, "count": 1, "min": 0.2840665384928385, "max": 0.2840665384928385}}}
# #metrics {"StartTime": 1639512063.905931, "EndTime": 1639512063.9059417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.2913043212890625, "count": 1, "min": 0.2913043212890625, "max": 0.2913043212890625}}}
# #metrics {"StartTime": 1639512063.9059806, "EndTime": 1639512063.9059918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.29031026204427085, "count": 1, "min": 0.29031026204427085, "max": 0.29031026204427085}}}
# #metrics {"StartTime": 1639512063.9060311, "EndTime": 1639512063.9060416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5876863810221354, "count": 1, "min": 0.5876863810221354, "max": 0.5876863810221354}}}
# #metrics {"StartTime": 1639512063.9060802, "EndTime": 1639512063.906091, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6141665852864583, "count": 1, "min": 0.6141665852864583, "max": 0.6141665852864583}}}
# #metrics {"StartTime": 1639512063.9061296, "EndTime": 1639512063.9061403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.643092305501302, "count": 1, "min": 0.643092305501302, "max": 0.643092305501302}}}
# #metrics {"StartTime": 1639512063.9061792, "EndTime": 1639512063.90619, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6752917277018229, "count": 1, "min": 0.6752917277018229, "max": 0.6752917277018229}}}
# #metrics {"StartTime": 1639512063.9062285, "EndTime": 1639512063.9062393, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4818456217447917, "count": 1, "min": 0.4818456217447917, "max": 0.4818456217447917}}}
# #metrics {"StartTime": 1639512063.9062784, "EndTime": 1639512063.906289, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.44917205810546873, "count": 1, "min": 0.44917205810546873, "max": 0.44917205810546873}}}
# #metrics {"StartTime": 1639512063.9063277, "EndTime": 1639512063.9063382, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.47636647542317706, "count": 1, "min": 0.47636647542317706, "max": 0.47636647542317706}}}
# #metrics {"StartTime": 1639512063.9063773, "EndTime": 1639512063.9063878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.4592706604003906, "count": 1, "min": 0.4592706604003906, "max": 0.4592706604003906}}}
# #metrics {"StartTime": 1639512063.906427, "EndTime": 1639512063.9064376, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7003963826497396, "count": 1, "min": 0.7003963826497396, "max": 0.7003963826497396}}}
# #metrics {"StartTime": 1639512063.906479, "EndTime": 1639512063.9064941, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6779300537109375, "count": 1, "min": 0.6779300537109375, "max": 0.6779300537109375}}}
# #metrics {"StartTime": 1639512063.9065518, "EndTime": 1639512063.9065683, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6699572143554687, "count": 1, "min": 0.6699572143554687, "max": 0.6699572143554687}}}
# #metrics {"StartTime": 1639512063.906634, "EndTime": 1639512063.9066536, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6619801839192708, "count": 1, "min": 0.6619801839192708, "max": 0.6619801839192708}}}
# #metrics {"StartTime": 1639512063.9067218, "EndTime": 1639512063.90674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.7065594278971354, "count": 1, "min": 0.7065594278971354, "max": 0.7065594278971354}}}
# #metrics {"StartTime": 1639512063.9068058, "EndTime": 1639512063.9068253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.696249979654948, "count": 1, "min": 0.696249979654948, "max": 0.696249979654948}}}
# #metrics {"StartTime": 1639512063.9068916, "EndTime": 1639512063.906911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.760311279296875, "count": 1, "min": 0.760311279296875, "max": 0.760311279296875}}}
# #metrics {"StartTime": 1639512063.9069676, "EndTime": 1639512063.9069853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6459283040364583, "count": 1, "min": 0.6459283040364583, "max": 0.6459283040364583}}}
# [12/14/2021 20:01:03 INFO 139845566875456] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.59407763671875
# [2021-12-14 20:01:04.083] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 153, "num_examples": 1, "num_bytes": 126960}
# #metrics {"StartTime": 1639512064.5021873, "EndTime": 1639512064.5023506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.559612108313519, "count": 1, "min": 0.559612108313519, "max": 0.559612108313519}}}
# #metrics {"StartTime": 1639512064.5025206, "EndTime": 1639512064.502547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.576029636548913, "count": 1, "min": 0.576029636548913, "max": 0.576029636548913}}}
# #metrics {"StartTime": 1639512064.5026145, "EndTime": 1639512064.5026333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6218519127887229, "count": 1, "min": 0.6218519127887229, "max": 0.6218519127887229}}}
# #metrics {"StartTime": 1639512064.5026934, "EndTime": 1639512064.502712, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6172423652980639, "count": 1, "min": 0.6172423652980639, "max": 0.6172423652980639}}}
# #metrics {"StartTime": 1639512064.5027695, "EndTime": 1639512064.5027854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.31485711802606997, "count": 1, "min": 0.31485711802606997, "max": 0.31485711802606997}}}
# #metrics {"StartTime": 1639512064.502836, "EndTime": 1639512064.5028515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3133597000785496, "count": 1, "min": 0.3133597000785496, "max": 0.3133597000785496}}}
# #metrics {"StartTime": 1639512064.5029008, "EndTime": 1639512064.5029156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3118755174719769, "count": 1, "min": 0.3118755174719769, "max": 0.3118755174719769}}}
# #metrics {"StartTime": 1639512064.5029635, "EndTime": 1639512064.502978, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.3166988206946332, "count": 1, "min": 0.3166988206946332, "max": 0.3166988206946332}}}
# #metrics {"StartTime": 1639512064.5030308, "EndTime": 1639512064.503048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.5904167507005774, "count": 1, "min": 0.5904167507005774, "max": 0.5904167507005774}}}
# #metrics {"StartTime": 1639512064.503102, "EndTime": 1639512064.50312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.6008044698963995, "count": 1, "min": 0.6008044698963995, "max": 0.6008044698963995}}}
# ...
# #metrics {"StartTime": 1639512072.4314177, "EndTime": 1639512072.4314258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.269226538616678, "count": 1, "min": 0.269226538616678, "max": 0.269226538616678}}}
# #metrics {"StartTime": 1639512072.4314518, "EndTime": 1639512072.43146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.2741990794306216, "count": 1, "min": 0.2741990794306216, "max": 0.2741990794306216}}}
# #metrics {"StartTime": 1639512072.431505, "EndTime": 1639512072.4315212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.2692311825959579, "count": 1, "min": 0.2692311825959579, "max": 0.2692311825959579}}}
# #metrics {"StartTime": 1639512072.4315825, "EndTime": 1639512072.4315994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.26925723863684614, "count": 1, "min": 0.26925723863684614, "max": 0.26925723863684614}}}
# #metrics {"StartTime": 1639512072.4316537, "EndTime": 1639512072.4316702, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.4718324080757473, "count": 1, "min": 0.4718324080757473, "max": 0.4718324080757473}}}
# #metrics {"StartTime": 1639512072.4317122, "EndTime": 1639512072.4317281, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.47099012291949727, "count": 1, "min": 0.47099012291949727, "max": 0.47099012291949727}}}
# #metrics {"StartTime": 1639512072.4317882, "EndTime": 1639512072.4318068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_binary_classification_cross_entropy_objective": {"sum": 0.
wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-12-14 20:01:12.597] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 132, "num_examples": 1, "num_bytes": 126960}
# [12/14/2021 20:01:12 INFO 139845566875456] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=sampled_accuracy, value=0.9239130434782774
# [12/14/2021 20:01:12 INFO 139845566875456] Epoch 14: Loss improved. Updating best model
# [2021-12-14 20:01:12.856] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 7, "num_examples": 1, "num_bytes": 126960}
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.2741990794306216)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('binary_classification_accuracy', 0.9217391304347826)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('binary_f_1.000', 0.9021739130434783)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('precision', 0.8829787234042553)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('recall', 0.9222222222222223)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('roc_auc_score', 0.9602777777777777)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [12/14/2021 20:01:12 INFO 139845566875456] #validation_score (algo-1) : ('binary_log_loss', 0.6173615098960967)
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation binary_classification_cross_entropy_objective <loss>=0.2741990794306216
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation binary_classification_accuracy <score>=0.9217391304347826
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation binary_f_1.000 <score>=0.9021739130434783
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation precision <score>=0.8829787234042553
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation recall <score>=0.9222222222222223
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation roc_auc_score <score>=0.9602777777777777
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation binary_balanced_accuracy <score>=0.5
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, validation binary_log_loss <score>=0.6173615098960967
# [12/14/2021 20:01:12 INFO 139845566875456] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.01, "l1": 0.0, "lr_scheduler_step": 100, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [12/14/2021 20:01:12 INFO 139845566875456] Saved checkpoint to "/tmp/tmpswe8p3aw/mx-mod-0000.params"
# [2021-12-14 20:01:12.871] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 9848, "num_examples": 1, "num_bytes": 126960}
# [2021-12-14 20:01:12.876] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 5, "num_examples": 1, "num_bytes": 126960}
# #metrics {"StartTime": 1639512072.8712206, "EndTime": 1639512072.8804162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 460.0, "count": 1, "min": 460, "max": 460}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 460.0, "count": 1, "min": 460, "max": 460}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 460.0, "count": 1, "min": 460, "max": 460}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.25257800558338994)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('binary_classification_accuracy', 0.9195652173913044)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('binary_f_1.000', 0.9038961038961039)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('precision', 0.8969072164948454)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('recall', 0.9109947643979057)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('roc_auc_score', 0.9639736078942758)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [12/14/2021 20:01:12 INFO 139845566875456] #test_score (algo-1) : ('binary_log_loss', 0.6055700960391746)
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test binary_classification_cross_entropy_objective <loss>=0.25257800558338994
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.9195652173913044
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.9038961038961039
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test precision <score>=0.8969072164948454
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test recall <score>=0.9109947643979057
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test roc_auc_score <score>=0.9639736078942758
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test binary_balanced_accuracy <score>=0.5
# [12/14/2021 20:01:12 INFO 139845566875456] #quality_metric: host=algo-1, test binary_log_loss <score>=0.6055700960391746
# #metrics {"StartTime": 1639512063.0169656, "EndTime": 1639512072.8861344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 190.582275390625, "count": 1, "min": 190.582275390625, "max": 190.582275390625}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 20.718812942504883, "count": 16, "min": 1.1036396026611328, "max": 1.8038749694824219}, "update.time": {"sum": 9157.475709915161, "count": 15, "min": 486.61231994628906, "max": 862.1275424957275}, "finalize.time": {"sum": 426.97954177856445, "count": 1, "min": 426.97954177856445, "max": 426.97954177856445}, "setuptime": {"sum": 40.93527793884277, "count": 1, "min": 40.93527793884277, "max": 40.93527793884277}, "totaltime": {"sum": 10158.042907714844, "count": 1, "min": 10158.042907714844, "max": 10158.042907714844}}}
#
# 2021-12-14 20:01:26 Uploading - Uploading generated training model
# 2021-12-14 20:01:26 Completed - Training job completed
# Training seconds: 80
# Billable seconds: 80

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how the model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a classification problem, you can check accuracy, precision, and recall.

# %%
sagemaker.analytics.TrainingJobAnalytics(binary_estimator._current_job_name, 
                                         metric_names = ['test:binary_classification_accuracy', 
                                                         'test:precision', 
                                                         'test:recall']
                                        ).dataframe()
# Out:
#    timestamp                          metric_name     value
# 0        0.0  test:binary_classification_accuracy  0.919565
# 1        0.0                       test:precision  0.896907
# 2        0.0                          test:recall  0.910995

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
binary_predictor = binary_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ------!

# %% [markdown]
# > ### Question 2 - Evaluation metric selection
# > You need to consider the business and its related restrictions when selecting the evaluation metric. In this case, spam detection requires being careful about false positives. A false positive means a good email is classified as a spam email. Because spam emails usually go to a spam folder, a user could lose important information from a false positive.
#
# >Some well-known evaluation metrics include the following:
# - Accuracy = ( TP + TN ) / ( TP + FP + FN + TN )
# - Precision = ( TP ) / ( TP + FP )
# - Recall = ( TP ) / ( TP + FN )
# >
# >In light of the provided information, which of the provided metrics do you think is the best to consider?

# %% [markdown]
# **Answer:** Precision is the choice of metric here as it accounts for the false positives. High precision means high TP and low FP.

# %% [markdown]
# Now that you have a hosted endpoint running, you can make real-time predictions from the model easily, simply by making an http POST request. First, you need to set up serializers and deserializers for passing the `test_features` NumPy arrays to the model behind the endpoint. You will also calculate the confusion matrix for the model to evaluate how it has done on the test data.

# %% [markdown]
# > ### Question 3 - Calculate metrics
# >
# > In this question, you are asked to calculate some important evaluation metrics. The accuracy calculation is used as an example. Calculate the precision and recall after accuracy.
# >
# >**Hint:** You can check your calculated values with the `sagemaker.analytics` results you got in the beginning of this section.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Get predictions for each batch with size of 25
def predict_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    # Parse protobuf responses to extract predicted labels
    extract_label = lambda x: x.label['predicted_label'].float32_tensor.values
    preds = np.concatenate([np.array([extract_label(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))

    # Calculate accuracy, precision, and recall
    accuracy = (preds == labels).sum() / len(labels)
    print(f'Accuracy: {accuracy}')
    
    # Calculate precision
    precision = (preds[preds == 1] == labels[preds == 1]).sum() / len(preds[preds == 1])
    print(f'Precision: {precision}')
    
    # Calculate recall
    recall = (preds[preds == 1] == labels[preds == 1]).sum() / len(labels[labels == 1])
    print(f'Recall: {recall}')
    
    confusion_matrix = pd.crosstab(index=labels, columns=np.round(preds), rownames=['True'], colnames=['predictions']).astype(int)
    plt.figure(figsize = (5,5))
    sns.heatmap(confusion_matrix, annot=True, fmt='.2f', cmap="YlGnBu").set_title('Confusion Matrix')

# %% [markdown]
# Get training performance

# %%
predict_batches(binary_predictor, train_features, train_labels)
# Out:
# Accuracy: 0.9195652173913044
# Precision: 0.8778877887788779
# Recall: 0.922970159611381

# %% [markdown]
# Get test performance

# %%
predict_batches(binary_predictor, test_features, test_labels)
# Out:
# Accuracy: 0.9195652173913044
# Precision: 0.8969072164948454
# Recall: 0.9109947643979057

# %% [markdown]
# > ### Question 4 - Compare training-test results
# > Do you see a big difference between training and test performance?

# %% [markdown]
# **Answer**: The two performances look very similar. We didn't experience overfitting here.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a binary classifier using the linear learning algorithm in Amazon SageMaker. You also reviewed important concepts such as training, validation, and test splits; confusion matrices; and classification metrics. Overall, the model resulted in over 90% in the accuracy, precision, and recall metrics.

# %% [markdown]
# ----------------------------------------------------------------------------
# # Problem 2: Diabetes progression prediction (regression)
#
# For regression, you will work with a health-related dataset to predict diabetes.
#
# You will use the [Diabetes Data](https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html).
#
# The __Scikit-learn__ library hosts this data as well. You will use this library to load the dataset.
#
# Fields in this dataset:
#
# Input:
# 1 - age
# 2 - sex
# 3 - bmi (Body mass index)
# 4 - bp (Blood pressure)
# 5 - s1 (Serum measurement 1)
# 6 - s2 (Serum measurement 2)
# 7 - s3 (Serum measurement 3)
# 8 - s4 (Serum measurement 4)
# 9 - s5 (Serum measurement 5)
# 10 - s6 (Serum measurement 6)
#
# Output:
# 11 - y (A quantitative measure of disease progression one year after baseline)

# %% [markdown]
# ## 1. Getting the data

# %%
import numpy as np
from sklearn.datasets import load_diabetes

diabetes = load_diabetes()
X, y = diabetes.data.astype(np.float32), diabetes.target.astype(np.float32)

print("X shape:", X.shape)
print("Y shape:", y.shape)
# Out:
# X shape: (442, 10)
# Y shape: (442,)

# %%
import pandas as pd

df = pd.DataFrame(data=np.column_stack((X, y)), 
                  columns=['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6', 'y']
                 )

# %% [markdown]
# **Note:** The features are normalized and scaled beforehand.

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6      y
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
for col in ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']:
    plt.hist(df[col].values)
    plt.title(col + ' distribution')
    plt.xlabel(col)
    plt.ylabel('Counts')
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
#%matplotlib inline
plt.hist(y)
plt.title('Target values')
plt.xlabel('y')
plt.ylabel('Counts')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 2. Training the model
#
# In this section, you will do the following:
#
# - Split the dataset into training, validation, and test subsets
# - Use the Amazon SageMaker linear learner algorithm to train the model

# %% [markdown]
# > ### Question 1 - Train-test-validation split
# >
# > An important part of training a machine learning model is splitting the data into training, validation, and test subsets. You will use the `train_test_split()` function from the `sklearn` library [documentation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# >Look at this example:
# >
# > `train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)`
# >
# > This function splits input feature `X` and target `y` pairs by a given ratio (test_size). This specific example splits the data into training (80%) and test (20%) subsets.
# >
# > Use this function __twice__ to split the data into __training (80%)__, __validation (10%)__, and __test (10%)__ subsets.

# %%
from sklearn.model_selection import train_test_split

# Get 80% of the data for training; the remaining 20% will be for validation and test
train_features, test_features, train_labels, test_labels = train_test_split(X, y, test_size=0.2)

# Split the remaining 20% of data as 10% test and 10% validation
test_features, val_features, test_labels, val_labels = train_test_split(test_features, test_labels, test_size=0.5)

print(f"Length of train_features is: {train_features.shape}")
print(f"Length of train_labels is: {train_labels.shape}")
print(f"Length of val_features is: {val_features.shape}")
print(f"Length of val_labels is: {val_labels.shape}")
print(f"Length of test_features is: {test_features.shape}")
print(f"Length of test_labels is: {test_labels.shape}")
# Out:
# Length of train_features is: (353, 10)
# Length of train_labels is: (353,)
# Length of val_features is: (45, 10)
# Length of val_labels is: (45,)
# Length of test_features is: (44, 10)
# Length of test_labels is: (44,)

# %% [markdown]
# Now, call the Amazon SageMaker `LinearLearner()` algorithm. This example uses an `ml.m4.xlarge` instance for training. `predictor_type` is set to __'regressor'__ because this is a regression problem.

# %%
import sagemaker

# Call the LinearLearner estimator object
regression_model = sagemaker.LinearLearner(role=sagemaker.get_execution_role(),
                                               instance_count=1,
                                               instance_type='ml.m4.xlarge',
                                               predictor_type='regressor')

# %% [markdown]
# Use the `record_set()` function of the binary_estimator to set the training, validation, and test parts of the estimator.

# %%
train_records = regression_model.record_set(train_features, train_labels, channel='train')
val_records = regression_model.record_set(val_features, val_labels, channel='validation')
test_records = regression_model.record_set(test_features, test_labels, channel='test')

# %% [markdown]
# The `fit()` function applies regression on this data.

# %%
regression_model.fit([train_records, val_records, test_records])
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2021-12-14 20:08:08 Starting - Starting the training job...
# 2021-12-14 20:08:31 Starting - Launching requested ML instancesProfilerReport-1639512487: InProgress
# ...
# 2021-12-14 20:08:59 Starting - Preparing the instances for training............
# 2021-12-14 20:11:09 Downloading - Downloading input data...
# 2021-12-14 20:11:38 Training - Downloading the training image...
# 2021-12-14 20:12:00 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [12/14/2021 20:12:07 INFO 140357435586368] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [12/14/2021 20:12:07 INFO 140357435586368] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '10', 'predictor_type': 'regressor', 'mini_batch_size': '353'}
# [12/14/2021 20:12:07 INFO 140357435586368] Final configuration: {'mini_batch_size': '353', 'epochs': '15', 'feature_dim': '10', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [12/14/2021 20:12:07 WARNING 140357435586368] Loggers have already been setup.
# Process 1 is a worker.
# [12/14/2021 20:12:07 INFO 140357435586368] Using default worker.
# [12/14/2021 20:12:08 INFO 140357435586368] Checkpoint loading and saving are disabled.
# [2021-12-14 20:12:08.208] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-12-14 20:12:08.209] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-12-14 20:12:08.226] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 18, "num_examples": 1, "num_bytes": 29652}
# [12/14/2021 20:12:08 INFO 140357435586368] Create Store: local
# [2021-12-14 20:12:08.266] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 39, "num_examples": 1, "num_bytes": 29652}
# [12/14/2021 20:12:08 INFO 140357435586368] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa723313f90>
# [12/14/2021 20:12:08 INFO 140357435586368] Scaling model computed with parameters:
#  {'stdev_label':
# [76.827255]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [0.04653485 0.04759179 0.04656277 0.04736031 0.04654401 0.04604102
#  0.04798566 0.04648983 0.04775254 0.04905363]
# <NDArray 10 @cpu(0)>, 'mean_label':
# [155.26628]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [0.00174023 0.00045392 0.00234021 0.00129316 0.00266804 0.0021037
#  0.00023126 0.0013571  0.00207203 0.00193794]
# <NDArray 10 @cpu(0)>}
# [12/14/2021 20:12:08 INFO 140357435586368] nvidia-smi: took 0.057 seconds to run.
# [12/14/2021 20:12:08 INFO 140357435586368] nvidia-smi identified 0 GPUs.
# [12/14/2021 20:12:08 INFO 140357435586368] Number of GPUs being used: 0
# #metrics {"StartTime": 1639512728.416777, "EndTime": 1639512728.4168172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 706.0, "count": 1, "min": 706, "max": 706}, "Total Batches Seen": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Max Records Seen Between Resets": {"sum": 353.0, "count": 1, "min": 353, "max": 353}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2021-12-14 20:12:08.469] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 52, "num_examples": 1, "num_bytes": 29652}
# #metrics {"StartTime": 1639512728.4700232, "EndTime": 1639512728.470152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8700264128341891, "count": 1, "min": 0.8700264128341891, "max": 0.8700264128341891}}}
# #metrics {"StartTime": 1639512728.4702742, "EndTime": 1639512728.4702995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 1.0268467370916696, "count": 1, "min": 1.0268467370916696, "max": 1.0268467370916696}}}
# #metrics {"StartTime": 1639512728.470363, "EndTime": 1639512728.4703817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.8234353214080206, "count": 1, "min": 0.8234353214080206, "max": 0.8234353214080206}}}
# #metrics {"StartTime": 1639512728.4704354, "EndTime": 1639512728.4704475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.1857012783839411, "count": 1, "min": 1.1857012783839411, "max": 1.1857012783839411}}}
# #metrics {"StartTime": 1639512728.4704857, "EndTime": 1639512728.4705024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 1.0558098206776736, "count": 1, "min": 1.0558098206776736, "max": 1.0558098206776736}}}
# #metrics {"StartTime": 1639512728.4705582, "EndTime": 1639512728.4705765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 1.0968187024167848, "count": 1, "min": 1.0968187024167848, "max": 1.0968187024167848}}}
# #metrics {"StartTime": 1639512728.4706318, "EndTime": 1639512728.4706511, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 1.075639416745972, "count": 1, "min": 1.075639416745972, "max": 1.075639416745972}}}
# #metrics {"StartTime": 1639512728.4707067, "EndTime": 1639512728.4707246, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 1.0095066146202196, "count": 1, "min": 1.0095066146202196, "max": 1.0095066146202196}}}
# #metrics {"StartTime": 1639512728.4707773, "EndTime": 1639512728.4707947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 1.1311182124756551, "count": 1, "min": 1.1311182124756551, "max": 1.1311182124756551}}}
# #metrics {"StartTime": 1639512728.4709666, "EndTime": 1639512728.471016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.0304657068873937, "count": 1, "min": 1.0304657068873937, "max": 1.0304657068873937}}}
# #metrics {"StartTime": 1639512728.4710932, "EndTime": 1639512728.4711146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.1565788636464236, "count": 1, "min": 1.1565788636464236, "max": 1.1565788636464236}}}
# #metrics {"StartTime": 1639512728.471178, "EndTime": 1639512728.4711983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.078971711501859, "count": 1, "min": 1.078971711501859, "max": 1.078971711501859}}}
# #metrics {"StartTime": 1639512728.4712553, "EndTime": 1639512728.4712749, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 1.0570275844325425, "count": 1, "min": 1.0570275844325425, "max": 1.0570275844325425}}}
# #metrics {"StartTime": 1639512728.4713385, "EndTime": 1639512728.4713588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.9522449180019475, "count": 1, "min": 0.9522449180019475, "max": 0.9522449180019475}}}
# #metrics {"StartTime": 1639512728.4714158, "EndTime": 1639512728.4714332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 1.0800900553846495, "count": 1, "min": 1.0800900553846495, "max": 1.0800900553846495}}}
# #metrics {"StartTime": 1639512728.4715302, "EndTime": 1639512728.4715507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 1.1468654556922804, "count": 1, "min": 1.1468654556922804, "max": 1.1468654556922804}}}
# #metrics {"StartTime": 1639512728.4716125, "EndTime": 1639512728.4716299, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 1.0030256492895715, "count": 1, "min": 1.0030256492895715, "max": 1.0030256492895715}}}
# #metrics {"StartTime": 1639512728.4716864, "EndTime": 1639512728.471703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8425271355734331, "count": 1, "min": 0.8425271355734331, "max": 0.8425271355734331}}}
# #metrics {"StartTime": 1639512728.4717662, "EndTime": 1639512728.4717836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.0863975114255047, "count": 1, "min": 1.0863975114255047, "max": 1.0863975114255047}}}
# #metrics {"StartTime": 1639512728.471846, "EndTime": 1639512728.4718645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9290400605026116, "count": 1, "min": 0.9290400605026116, "max": 0.9290400605026116}}}
# #metrics {"StartTime": 1639512728.4719198, "EndTime": 1639512728.471937, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.9880486939513987, "count": 1, "min": 0.9880486939513987, "max": 0.9880486939513987}}}
# #metrics {"StartTime": 1639512728.47199, "EndTime": 1639512728.4720066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 1.066697766355347, "count": 1, "min": 1.066697766355347, "max": 1.066697766355347}}}
# #metrics {"StartTime": 1639512728.4720597, "EndTime": 1639512728.4720774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 1.013808382806967, "count": 1, "min": 1.013808382806967, "max": 1.013808382806967}}}
# #metrics {"StartTime": 1639512728.4721324, "EndTime": 1639512728.4721506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 1.0680187538730523, "count": 1, "min": 1.0680187538730523, "max": 1.0680187538730523}}}
# #metrics {"StartTime": 1639512728.4722059, "EndTime": 1639512728.472225, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9836614246746636, "count": 1, "min": 0.9836614246746636, "max": 0.9836614246746636}}}
# #metrics {"StartTime": 1639512728.4722838, "EndTime": 1639512728.4723027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9847572910211579, "count": 1, "min": 0.9847572910211579, "max": 0.9847572910211579}}}
# #metrics {"StartTime": 1639512728.472371, "EndTime": 1639512728.4723911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.019553986892484, "count": 1, "min": 1.019553986892484, "max": 1.019553986892484}}}
# #metrics {"StartTime": 1639512728.4724567, "EndTime": 1639512728.4724748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.2773780714688827, "count": 1, "min": 1.2773780714688827, "max": 1.2773780714688827}}}
# #metrics {"StartTime": 1639512728.472544, "EndTime": 1639512728.4725635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.084913302413465, "count": 1, "min": 1.084913302413465, "max": 1.084913302413465}}}
# #metrics {"StartTime": 1639512728.4726198, "EndTime": 1639512728.4726377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 0.7848436393413598, "count": 1, "min": 0.7848436393413598, "max": 0.7848436393413598}}}
# #metrics {"StartTime": 1639512728.4726927, "EndTime": 1639512728.4727097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.9269392753795591, "count": 1, "min": 0.9269392753795591, "max": 0.9269392753795591}}}
# #metrics {"StartTime": 1639512728.4727643, "EndTime": 1639512728.4727824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 1.0008727335727248, "count": 1, "min": 1.0008727335727248, "max": 1.0008727335727248}}}
# [12/14/2021 20:12:08 INFO 140357435586368] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.8700264128341891
# [2021-12-14 20:12:08.514] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 0, "duration": 305, "num_examples": 1, "num_bytes": 3780}
# [2021-12-14 20:12:08.525] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 2, "duration": 10, "num_examples": 1, "num_bytes": 3780}
# #metrics {"StartTime": 1639512728.5326436, "EndTime": 1639512728.5327053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 5257.5881944444445, "count": 1, "min": 5257.5881944444445, "max": 5257.5881944444445}}}
# #metrics {"StartTime": 1639512728.5327966, "EndTime": 1639512728.5328188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 6710.830555555555, "count": 1, "min": 6710.830555555555, "max": 6710.830555555555}}}
# #metrics {"StartTime": 1639512728.5328877, "EndTime": 1639512728.532908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 4710.073611111111, "count": 1, "min": 4710.073611111111, "max": 4710.073611111111}}}
# #metrics {"StartTime": 1639512728.532963, "EndTime": 1639512728.5329819, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 7340.345138888889, "count": 1, "min": 7340.345138888889, "max": 7340.345138888889}}}
# #metrics {"StartTime": 1639512728.5330422, "EndTime": 1639512728.533062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 4382.592708333334, "count": 1, "min": 4382.592708333334, "max": 4382.592708333334}}}
# #metrics {"StartTime": 1639512728.5331075, "EndTime": 1639512728.5331187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 5054.315972222223, "count": 1, "min": 5054.315972222223, "max": 5054.315972222223}}}
# #metrics {"StartTime": 1639512728.5331547, "EndTime": 1639512728.533165, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 4660.648958333333, "count": 1, "min": 4660.648958333333, "max": 4660.648958333333}}}
# #metrics {"StartTime": 1639512728.5332105, "EndTime": 1639512728.5332286, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 4769.441319444444, "count": 1, "min": 4769.441319444444, "max": 4769.441319444444}}}
# #metrics {"StartTime": 1639512728.5332701, "EndTime": 1639512728.5332797, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 7602.325, "count": 1, "min": 7602.325, "max": 7602.325}}}
# #metrics {"StartTime": 1639512728.5333157, "EndTime": 1639512728.533326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 6575.083333333333, "count": 1, "min": 6575.083333333333, "max": 6575.083333333333}}}
# #metrics {"StartTime": 1639512728.533363, "EndTime": 1639512728.5333784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 6897.225, "count": 1, "min": 6897.225, "max": 6897.225}}}
# #metrics {"StartTime": 1639512728.5334356, "EndTime": 1639512728.5334525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 6632.451388888889, "count": 1, "min": 6632.451388888889, "max": 6632.451388888889}}}
# #metrics {"StartTime": 1639512728.5335126, "EndTime": 1639512728.5335312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 4997.599652777778, "count": 1, "min": 4997.599652777778, "max": 4997.599652777778}}}
# #metrics {"StartTime": 1639512728.5335853, "EndTime": 1639512728.5336027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 4449.529166666666, "count": 1, "min": 4449.529166666666, "max": 4449.529166666666}}}
# #metrics {"StartTime": 1639512728.533656, "EndTime": 1639512728.5336747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 4872.320833333333, "count": 1, "min": 4872.320833333333, "max": 4872.320833333333}}}
# #metrics {"StartTime": 1639512728.533726, "EndTime": 1639512728.5337427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 4252.309375, "count": 1, "min": 4252.309375, "max": 4252.309375}}}
# #metrics {"StartTime": 1639512728.5338, "EndTime": 1639512728.5338178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 5829.517361111111, "count": 1, "min": 5829.517361111111, "max": 5829.517361111111}}}
# #metrics {"StartTime": 1639512728.5338717, "EndTime": 1639512728.5338886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 5107.179513888889, "count": 1, "min": 5107.179513888889, "max": 5107.179513888889}}}
# #metrics {"StartTime": 1639512728.5339403, "EndTime": 1639512728.5339577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 6627.925694444444, "count": 1, "min": 6627.925694444444, "max": 6627.925694444444}}}
# #metrics {"StartTime": 1639512728.5340097, "EndTime": 1639512728.5340278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 5587.039930555556, "count": 1, "min": 5587.039930555556, "max": 5587.039930555556}}}
# #metrics {"StartTime": 1639512728.5340805, "EndTime": 1639512728.534098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 4755.746180555556, "count": 1, "min": 4755.746180555556, "max": 4755.746180555556}}}
# #metrics {"StartTime": 1639512728.5341508, "EndTime": 1639512728.5341694, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 5017.723263888889, "count": 1, "min": 5017.723263888889, "max": 5017.723263888889}}}
# #metrics {"StartTime": 1639512728.5342226, "EndTime": 1639512728.5342402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 3947.0875, "count": 1, "min": 3947.0875, "max": 3947.0875}}}
# #metrics {"StartTime": 1639512728.5342894, "EndTime": 1639512728.5343058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 4521.086805555556, "count": 1, "min": 4521.086805555556, "max": 4521.086805555556}}}
# #metrics {"StartTime": 1639512728.5343559, "EndTime": 1639512728.534373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6372.275, "count": 1, "min": 6372.275, "max": 6372.275}}}
# #metrics {"StartTime": 1639512728.5344374, "EndTime": 1639512728.5344558, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 6040.079861111111, "count": 1, "min": 6040.079861111111, "max": 6040.079861111111}}}
# #metrics {"StartTime": 1639512728.534512, "EndTime": 1639512728.5345306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 6171.343055555555, "count": 1, "min": 6171.343055555555, "max": 6171.343055555555}}}
# #metrics {"StartTime": 1639512728.5345962, "EndTime": 1639512728.534614, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 8109.689583333334, "count": 1, "min": 8109.689583333334, "max": 8109.689583333334}}}
# #metrics {"StartTime": 1639512728.53467, "EndTime": 1639512728.534687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 6661.211805555556, "count": 1, "min": 6661.211805555556, "max": 6661.211805555556}}}
# #metrics {"StartTime": 1639512728.5347414, "EndTime": 1639512728.5347576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 11875.6, "count": 1, "min": 11875.6, "max": 11875.6}}}
# #metrics {"StartTime": 1639512728.5348203, "EndTime": 1639512728.5348394, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 7953.294444444445, "count": 1, "min": 7953.294444444445, "max": 7953.294444444445}}}
# #metrics {"StartTime": 1639512728.5349302, "EndTime": 1639512728.5349505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 6342.143055555555, "count": 1, "min": 6342.143055555555, "max": 6342.143055555555}}}
# [12/14/2021 20:12:08 INFO 140357435586368] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=5257.5881944444445
# [12/14/2021 20:12:08 INFO 140357435586368] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=3947.0875
# [12/14/2021 20:12:08 INFO 140357435586368] Epoch 0: Loss improved. Updating best model
# [12/14/2021 20:12:08 INFO 140357435586368] Saving model for epoch: 0
# [12/14/2021 20:12:08 INFO 140357435586368] Saved checkpoint to "/tmp/tmpageot6fv/mx-mod-0000.params"
# [12/14/2021 20:12:08 INFO 140357435586368] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1639512728.4171846, "EndTime": 1639512728.5494921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1059.0, "count": 1, "min": 1059, "max": 1059}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 353.0, "count": 1, "min": 353, "max": 353}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 353.0, "count": 1, "min": 353, "max": 353}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/14/2021 20:12:08 INFO 140357435586368] #throughput_metric: host=algo-1, train throughput=2664.718078855059 records/second
# [2021-12-14 20:12:08.574] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 24, "num_examples": 1, "num_bytes": 29652}
# #metrics {"StartTime": 1639512728.5741465, "EndTime": 1639512728.574246, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.8435764042581445, "count": 1, "min": 0.8435764042581445, "max": 0.8435764042581445}}}
# #metrics {"StartTime": 1639512728.5743403, "EndTime": 1639512728.574365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.9910051815908286, "count": 1, "min": 0.9910051815908286, "max": 0.9910051815908286}}}
# #metrics {"StartTime": 1639512728.5744307, "EndTime": 1639512728.574451, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 0.7956543833270627, "count": 1, "min": 0.7956543833270627, "max": 0.7956543833270627}}}
# #metrics {"StartTime": 1639512728.5745125, "EndTime": 1639512728.5745313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 1.1443581729705206, "count": 1, "min": 1.1443581729705206, "max": 1.1443581729705206}}}
# #metrics {"StartTime": 1639512728.5745926, "EndTime": 1639512728.574611, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.708138052532423, "count": 1, "min": 0.708138052532423, "max": 0.708138052532423}}}
# #metrics {"StartTime": 1639512728.5746682, "EndTime": 1639512728.5746875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.7779280794916342, "count": 1, "min": 0.7779280794916342, "max": 0.7779280794916342}}}
# #metrics {"StartTime": 1639512728.5747452, "EndTime": 1639512728.574763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.7631581768435729, "count": 1, "min": 0.7631581768435729, "max": 0.7631581768435729}}}
# #metrics {"StartTime": 1639512728.5748203, "EndTime": 1639512728.5748389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.76350588703966, "count": 1, "min": 0.76350588703966, "max": 0.76350588703966}}}
# #metrics {"StartTime": 1639512728.5749254, "EndTime": 1639512728.5749464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 1.0904524589733091, "count": 1, "min": 1.0904524589733091, "max": 1.0904524589733091}}}
# #metrics {"StartTime": 1639512728.575006, "EndTime": 1639512728.575024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 0.9948975128087376, "count": 1, "min": 0.9948975128087376, "max": 0.9948975128087376}}}
# #metrics {"StartTime": 1639512728.5750823, "EndTime": 1639512728.5751004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 1.1152318678901825, "count": 1, "min": 1.1152318678901825, "max": 1.1152318678901825}}}
# #metrics {"StartTime": 1639512728.5751595, "EndTime": 1639512728.575178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0428841134306392, "count": 1, "min": 1.0428841134306392, "max": 1.0428841134306392}}}
# #metrics {"StartTime": 1639512728.575236, "EndTime": 1639512728.5752535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.7929298465717953, "count": 1, "min": 0.7929298465717953, "max": 0.7929298465717953}}}
# #metrics {"StartTime": 1639512728.5753217, "EndTime": 1639512728.575341, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.7387187838892085, "count": 1, "min": 0.7387187838892085, "max": 0.7387187838892085}}}
# #metrics {"StartTime": 1639512728.5754037, "EndTime": 1639512728.5754225, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.7873685582839058, "count": 1, "min": 0.7873685582839058, "max": 0.7873685582839058}}}
# #metrics {"StartTime": 1639512728.5754783, "EndTime": 1639512728.575497, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.697327049190532, "count": 1, "min": 0.697327049190532, "max": 0.697327049190532}}}
# #metrics {"StartTime": 1639512728.575552, "EndTime": 1639512728.5755687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9679402035289041, "count": 1, "min": 0.9679402035289041, "max": 0.9679402035289041}}}
# #metrics {"StartTime": 1639512728.575624, "EndTime": 1639512728.5756419, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8155249576730701, "count": 1, "min": 0.8155249576730701, "max": 0.8155249576730701}}}
# #metrics {"StartTime": 1639512728.575697, "EndTime": 1639512728.5757146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.047980808333702, "count": 1, "min": 1.047980808333702, "max": 1.047980808333702}}}
# #metrics {"StartTime": 1639512728.5757732, "EndTime": 1639512728.5757923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9002168563540192, "count": 1, "min": 0.9002168563540192, "max": 0.9002168563540192}}}
# #metrics {"StartTime": 1639512728.575842, "EndTime": 1639512728.5758603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.726965107255887, "count": 1, "min": 0.726965107255887, "max": 0.726965107255887}}}
# #metrics {"StartTime": 1639512728.5759084, "EndTime": 1639512728.5759265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.7384317630411208, "count": 1, "min": 0.7384317630411208, "max": 0.7384317630411208}}}
# #metrics {"StartTime": 1639512728.57598, "EndTime": 1639512728.575996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.7145102611682232, "count": 1, "min": 0.7145102611682232, "max": 0.7145102611682232}}}
# #metrics {"StartTime": 1639512728.5760403, "EndTime": 1639512728.5760531, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.7054269590729019, "count": 1, "min": 0.7054269590729019, "max": 0.7054269590729019}}}
# #metrics {"StartTime": 1639512728.5760965, "EndTime": 1639512728.57611, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9849971954950868, "count": 1, "min": 0.9849971954950868, "max": 0.9849971954950868}}}
# #metrics {"StartTime": 1639512728.5761518, "EndTime": 1639512728.5761647, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9741670862473442, "count": 1, "min": 0.9741670862473442, "max": 0.9741670862473442}}}
# #metrics {"StartTime": 1639512728.576208, "EndTime": 1639512728.5762243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.015619380615926, "count": 1, "min": 1.015619380615926, "max": 1.015619380615926}}}
# #metrics {"StartTime": 1639512728.5762727, "EndTime": 1639512728.5762868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.2524804825823301, "count": 1, "min": 1.2524804825823301, "max": 1.2524804825823301}}}
# #metrics {"StartTime": 1639512728.5763328, "EndTime": 1639512728.5763469, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.9953692817147662, "count": 1, "min": 0.9953692817147662, "max": 0.9953692817147662}}}
# #metrics {"StartTime": 1639512728.57639, "EndTime": 1639512728.5764043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.624222623052408, "count": 1, "min": 1.624222623052408, "max": 1.624222623052408}}}
# #metrics {"StartTime": 1639512728.5764496, "EndTime": 1639512728.5764637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 1.2351758919086402, "count": 1, "min": 1.2351758919086402, "max": 1.2351758919086402}}}
# #metrics {"StartTime": 1639512728.5765073, "EndTime": 1639512728.5765207, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9432021186979904, "count": 1, "min": 0.9432021186979904, "max": 0.9432021186979904}}}
# [12/14/2021 20:12:08 INFO 140357435586368] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.8435764042581445
# [2021-12-14 20:12:08.627] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 5, "duration": 18, "num_examples": 1, "num_bytes": 3780}
# #metrics {"StartTime": 1639512728.6413867, "EndTime": 1639512728.6415334, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 5052.673958333334, "count": 1, "min": 5052.673958333334, "max": 5052.673958333334}}}
# #metrics {"StartTime": 1639512728.641689, "EndTime": 1639512728.6417184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 6408.202777777778, "count": 1, "min": 6408.202777777778, "max": 6408.202777777778}}}
# #metrics {"StartTime": 1639512728.6417952, "EndTime": 1639512728.6418152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 4499.761111111111, "count": 1, "min": 4499.761111111111, "max": 4499.761111111111}}}
# #metrics {"StartTime": 1639512728.6418784, "EndTime": 1639512728.6418982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 7000.679166666667, "count": 1, "min": 7000.679166666667, "max": 7000.679166666667}}}
# #metrics {"StartTime": 1639512728.641956, "EndTime": 1639512728.6419733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 6225.138194444445, "count": 1, "min": 6225.138194444445, "max": 6225.138194444445}}}
# #metrics {"StartTime": 1639512728.642023, "EndTime": 1639512728.6420395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 6444.416666666667, "count": 1, "min": 6444.416666666667, "max": 6444.416666666667}}}
# #metrics {"StartTime": 1639512728.6420875, "EndTime": 1639512728.6421046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 6340.406944444445, "count": 1, "min": 6340.406944444445, "max": 6340.406944444445}}}
# #metrics {"StartTime": 1639512728.642156, "EndTime": 1639512728.6421723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 6316.585416666667, "count": 1, "min": 6316.585416666667, "max": 6316.585416666667}}}
# #metrics {"StartTime": 1639512728.6422262, "EndTime": 1639512728.6422448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 7261.611805555555, "count": 1, "min": 7261.611805555555, "max": 7261.611805555555}}}
# #metrics {"StartTime": 1639512728.642299, "EndTime": 1639512728.6423151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 6287.4375, "count": 1, "min": 6287.4375, "max": 6287.4375}}}
# #metrics {"StartTime": 1639512728.642365, "EndTime": 1639512728.6423805, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 6573.3173611111115, "count": 1, "min": 6573.3173611111115, "max": 6573.3173611111115}}}
# #metrics {"StartTime": 1639512728.64243, "EndTime": 1639512728.6424468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 6339.792361111111, "count": 1, "min": 6339.792361111111, "max": 6339.792361111111}}}
# #metrics {"StartTime": 1639512728.642501, "EndTime": 1639512728.6425188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 6290.954861111111, "count": 1, "min": 6290.954861111111, "max": 6290.954861111111}}}
# #metrics {"StartTime": 1639512728.6425686, "EndTime": 1639512728.642585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 6232.310416666666, "count": 1, "min": 6232.310416666666, "max": 6232.310416666666}}}
# #metrics {"StartTime": 1639512728.642634, "EndTime": 1639512728.6426506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 6289.277777777777, "count": 1, "min": 6289.277777777777, "max": 6289.277777777777}}}
# #metrics {"StartTime": 1639512728.6427038, "EndTime": 1639512728.642722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 6357.678472222222, "count": 1, "min": 6357.678472222222, "max": 6357.678472222222}}}
# #metrics {"StartTime": 1639512728.642776, "EndTime": 1639512728.6427932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 5561.392013888889, "count": 1, "min": 5561.392013888889, "max": 5561.392013888889}}}
# #metrics {"StartTime": 1639512728.6428442, "EndTime": 1639512728.6428833, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 4865.469097222222, "count": 1, "min": 4865.469097222222, "max": 4865.469097222222}}}
# #metrics {"StartTime": 1639512728.6429398, "EndTime": 1639512728.6429574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 6314.274305555556, "count": 1, "min": 6314.274305555556, "max": 6314.274305555556}}}
# #metrics {"StartTime": 1639512728.6430092, "EndTime": 1639512728.6430266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 5363.169444444445, "count": 1, "min": 5363.169444444445, "max": 5363.169444444445}}}
# #metrics {"StartTime": 1639512728.6430814, "EndTime": 1639512728.6431003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 5657.158680555555, "count": 1, "min": 5657.158680555555, "max": 5657.158680555555}}}
# #metrics {"StartTime": 1639512728.643154, "EndTime": 1639512728.6431715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 5912.405555555555, "count": 1, "min": 5912.405555555555, "max": 5912.405555555555}}}
# #metrics {"StartTime": 1639512728.6432257, "EndTime": 1639512728.6432428, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 5431.796180555555, "count": 1, "min": 5431.796180555555, "max": 5431.796180555555}}}
# #metrics {"StartTime": 1639512728.6432984, "EndTime": 1639512728.643316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 5831.675, "count": 1, "min": 5831.675, "max": 5831.675}}}
# #metrics {"StartTime": 1639512728.643371, "EndTime": 1639512728.643389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6269.063194444445, "count": 1, "min": 6269.063194444445, "max": 6269.063194444445}}}
# #metrics {"StartTime": 1639512728.643446, "EndTime": 1639512728.6434646, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 5975.133333333333, "count": 1, "min": 5975.133333333333, "max": 5975.133333333333}}}
# #metrics {"StartTime": 1639512728.6435173, "EndTime": 1639512728.6435342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 6100.66875, "count": 1, "min": 6100.66875, "max": 6100.66875}}}
# ...
# #metrics {"StartTime": 1639512729.8712008, "EndTime": 1639512729.8712158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 2681.046354166667, "count": 1, "min": 2681.046354166667, "max": 2681.046354166667}}}
# #metrics {"StartTime": 1639512729.8712618, "EndTime": 1639512729.8712761, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 2579.0180555555557, "count": 1, "min": 2579.0180555555557, "max": 2579.0180555555557}}}
# #metrics {"StartTime": 1639512729.8713222, "EndTime": 1639512729.8713355, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 4862.869791666667, "count": 1, "min": 4862.869791666667, "max": 4862.869791666667}}}
# #metrics {"StartTime": 1639512729.8713791, "EndTime": 1639512729.8713927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 4278.365972222222, "count": 1, "min": 4278.365972222222, "max": 4278.365972222222}}}
# #metrics {"StartTime": 1639512729.8714368, "EndTime": 1639512729.8714507, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 4418.038541666667, "count": 1, "min": 4418.038541666667, "max": 4418.038541666667}}}
# #metrics {"StartTime": 1639512729.8714943, "EndTime": 1639512729.8715076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 4409.6149305555555, "count": 1, "min": 4409.6149305555555, "max": 4409.6149305555555}}}
# #metrics {"StartTime": 1639512729.871552, "EndTime": 1639512729.8715656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 2649.0206597222223, "count": 1, "min": 2649.0206597222223, "max": 2649.0206597222223}}}
# #metrics {"StartTime": 1639512729.8716133, "EndTime": 1639512729.871627, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 2537.2538194444446, "count": 1, "min": 2537.2538194444446, "max": 2537.2538194444446}}}
# #metrics {"StartTime": 1639512729.8716779, "EndTime": 1639512729.8716946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 2681.3909722222224, "count": 1, "min": 2681.3909722222224, "max": 2681.3909722222224}}}
# #metrics {"StartTime": 1639512729.8717442, "EndTime": 1639512729.8717594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 3105.478125, "count": 1, "min": 3105.478125, "max": 3105.478125}}}
# #metrics {"StartTime": 1639512729.8718066, "EndTime": 1639512729.8718238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 4028.3104166666667, "count": 1, "min": 4028.3104166666667, "max": 4028.3104166666667}}}
# #metrics {"StartTime": 1639512729.871877, "EndTime": 1639512729.871893, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 3518.1746527777777, "count": 1, "min": 3518.1746527777777, "max": 3518.1746527777777}}}
# #metrics {"StartTime": 1639512729.8719416, "EndTime": 1639512729.8719559, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 4447.054513888889, "count": 1, "min": 4447.054513888889, "max": 4447.054513888889}}}
# #metrics {"StartTime": 1639512729.8720055, "EndTime": 1639512729.8720217, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 4018.6086805555556, "count": 1, "min": 4018.6086805555556, "max": 4018.6086805555556}}}
# #metrics {"StartTime": 1639512729.8720758, "EndTime": 1639512729.8720922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 3716.851736111111, "count": 1, "min": 3716.851736111111, "max": 3716.851736111111}}}
# #metrics {"StartTime": 1639512729.8721395, "EndTime": 1639512729.8721564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 3674.4743055555555, "count": 1, "min": 3674.4743055555555, "max": 3674.4743055555555}}}
# #metrics {"StartTime": 1639512729.8722074, "EndTime": 1639512729.8722248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 3330.1052083333334, "count": 1, "min": 3330.1052083333334, "max": 3330.1052083333334}}}
# #metrics {"StartTime": 1639512729.8722768, "EndTime": 1639512729.8722942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 3451.055208333333, "count": 1, "min": 3451.055208333333, "max": 3451.055208333333}}}
# #metrics {"StartTime": 1639512729.872348, "EndTime": 1639512729.8723652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 6109.303472222222, "count": 1, "min": 6109.303472222222, "max": 6109.303472222222}}}
# #metrics {"StartTime": 1639512729.872416, "EndTime": 1639512729.8724327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 6157.579166666666, "count": 1, "min": 6157.579166666666, "max": 6157.579166666666}}}
# #metrics {"StartTime": 1639512729.8725007, "EndTime": 1639512729.8725197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 6002.639583333334, "count": 1, "min": 6002.639583333334, "max": 6002.639583333334}}}
# #metrics {"StartTime": 1639512729.872581, "EndTime": 1639512729.872598, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 6025.092361111111, "count": 1, "min": 6025.092361111111, "max": 6025.092361111111}}}
# #metrics {"StartTime": 1639512729.8726568, "EndTime": 1639512729.8726737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 6307.038888888889, "count": 1, "min": 6307.038888888889, "max": 6307.038888888889}}}
# #metrics {"StartTime": 1639512729.8727372, "EndTime": 1639512729.8727553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 5033.495486111111, "count": 1, "min": 5033.495486111111, "max": 5033.495486111111}}}
# #metrics {"StartTime": 1639512729.8728154, "EndTime": 1639512729.8728316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 5728.761111111111, "count": 1, "min": 5728.761111111111, "max": 5728.761111111111}}}
# #metrics {"StartTime": 1639512729.872891, "EndTime": 1639512729.8729067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 6297.208333333333, "count": 1, "min": 6297.208333333333, "max": 6297.208333333333}}}
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, epoch=14, validation mse_objective <loss>=3735.034375
# [12/14/2021 20:12:09 INFO 140357435586368] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=2537.2538194444446
# [12/14/2021 20:12:09 INFO 140357435586368] Epoch 14: Loss has not improved for 0 epochs.
# [12/14/2021 20:12:09 INFO 140357435586368] Saving model for epoch: 14
# [12/14/2021 20:12:09 INFO 140357435586368] Saved checkpoint to "/tmp/tmp7_2oynqq/mx-mod-0000.params"
# [12/14/2021 20:12:09 INFO 140357435586368] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1639512729.7853022, "EndTime": 1639512729.88097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 6001.0, "count": 1, "min": 6001, "max": 6001}, "Total Batches Seen": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Max Records Seen Between Resets": {"sum": 353.0, "count": 1, "min": 353, "max": 353}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 353.0, "count": 1, "min": 353, "max": 353}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/14/2021 20:12:09 INFO 140357435586368] #throughput_metric: host=algo-1, train throughput=3684.7170293092163 records/second
# [12/14/2021 20:12:09 WARNING 140357435586368] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/14/2021 20:12:09 WARNING 140357435586368] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-12-14 20:12:09.923] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 47, "duration": 13, "num_examples": 1, "num_bytes": 3780}
# [12/14/2021 20:12:09 INFO 140357435586368] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=2537.2538194444446
# [2021-12-14 20:12:09.938] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 49, "duration": 2, "num_examples": 1, "num_bytes": 3780}
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('mse_objective', 2323.8734375)
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('mse', 2323.8734375)
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('absolute_loss', 39.29593098958333)
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('rmse', 48.20657048058905)
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('r2', 0.6247224497385073)
# [12/14/2021 20:12:09 INFO 140357435586368] #validation_score (algo-1) : ('mae', 39.29593048095703)
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation mse_objective <loss>=2323.8734375
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation mse <loss>=2323.8734375
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation absolute_loss <loss>=39.29593098958333
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation rmse <loss>=48.20657048058905
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation r2 <loss>=0.6247224497385073
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, validation mae <loss>=39.29593048095703
# [12/14/2021 20:12:09 INFO 140357435586368] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [12/14/2021 20:12:09 INFO 140357435586368] Saved checkpoint to "/tmp/tmpty1gnjtv/mx-mod-0000.params"
# [2021-12-14 20:12:09.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 1736, "num_examples": 1, "num_bytes": 3696}
# [2021-12-14 20:12:09.948] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 2, "num_examples": 1, "num_bytes": 3696}
# #metrics {"StartTime": 1639512729.9463723, "EndTime": 1639512729.9496818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 44.0, "count": 1, "min": 44, "max": 44}, "Total Batches Seen": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Max Records Seen Between Resets": {"sum": 44.0, "count": 1, "min": 44, "max": 44}, "Max Batches Seen Between Resets": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 44.0, "count": 1, "min": 44, "max": 44}, "Number of Batches Since Last Reset": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('mse_objective', 2805.6889204545455)
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('mse', 2805.6889204545455)
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('absolute_loss', 44.69893022017045)
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('rmse', 52.968754190131236)
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('r2', 0.48603734748695926)
# [12/14/2021 20:12:09 INFO 140357435586368] #test_score (algo-1) : ('mae', 44.69892969998446)
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test mse_objective <loss>=2805.6889204545455
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test mse <loss>=2805.6889204545455
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test absolute_loss <loss>=44.69893022017045
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test rmse <loss>=52.968754190131236
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test r2 <loss>=0.48603734748695926
# [12/14/2021 20:12:09 INFO 140357435586368] #quality_metric: host=algo-1, test mae <loss>=44.69892969998446
# #metrics {"StartTime": 1639512728.2072122, "EndTime": 1639512729.9545972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 206.6643238067627, "count": 1, "min": 206.6643238067627, "max": 206.6643238067627}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 11.751413345336914, "count": 16, "min": 0.2224445343017578, "max": 1.6710758209228516}, "update.time": {"sum": 1401.085615158081, "count": 15, "min": 77.13937759399414, "max": 123.04449081420898}, "finalize.time": {"sum": 62.01434135437012, "count": 1, "min": 62.01434135437012, "max": 62.01434135437012}, "setuptime": {"sum": 40.85063934326172, "count": 1, "min": 40.85063934326172, "max": 40.85063934326172}, "totaltime": {"sum": 2082.5908184051514, "count": 1, "min": 2082.5908184051514, "max": 2082.5908184051514}}}
#
# 2021-12-14 20:12:32 Uploading - Uploading generated training model
# 2021-12-14 20:12:32 Completed - Training job completed
# Training seconds: 69
# Billable seconds: 69

# %% [markdown]
# ## 3. Evaluating the model
#
# In this section, you will look at how your model performs with the test dataset.

# %% [markdown]
# ### Amazon SageMaker analytics
# You can use `sagemaker.analytics` to get some performance metrics. This doesn't require deploying the model. Because this is a regression problem, you can check the **mean squared error**.

# %%
sagemaker.analytics.TrainingJobAnalytics(regression_model._current_job_name, 
                                         metric_names = ['test:mse']
                                        ).dataframe()
# Out:
#    timestamp metric_name       value
# 0        0.0    test:mse  2805.68892

# %% [markdown]
# ### Deploying the model
# To deploy the model, run the following cell.
#
# **Note:** This takes some time to complete. While you are waiting, think about the answer to question 2.

# %%
regression_predictor = regression_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ------!

# %% [markdown]
# >### Question 2 - Calculate mean squared error
# >
# >In this question, you will calculate the mean squared error. It is given by this equation:
# >
# >mean squared error = $\displaystyle\frac{1}{n}\sum_{t=1}^{n}(pred_t-target_t)^2$
# >
# >Calculate the mean squared error using the __preds__ and __labels__ variables and print it.

# %%
import matplotlib.pyplot as plt

# Get predictions for each batch with size of 25
def predict_regression_batches(predictor, features, labels):
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(features, 25)]
    
    # Parse protobuf responses to extract predicted labels
    extract_score = lambda x: x.label['score'].float32_tensor.values
    preds = np.concatenate([np.array([extract_score(x) for x in batch]) for batch in prediction_batches])
    preds = preds.reshape((-1,))
    
    # Calculate mean squared error
    mse = sum((preds - labels)**2) / len(preds)
    print(mse)
    
    return preds

# %% [markdown]
# Now, get the results on the training and test subsets.

# %%
train_predictions = predict_regression_batches(regression_predictor, train_features, train_labels)
# Out:
# 3195.0980629571436

# %%
test_predictions = predict_regression_batches(regression_predictor, test_features, test_labels)
# Out:
# 2805.6889354965997

# %% [markdown]
# ### Plotting results
#
# Let's look at some plots. Even though you calculated the mean squared error, it is still a good idea to examine the results visually.

# %% [markdown]
# ### Scatter plot
#
# With the scatter plot, you look at the fitted (predicted) values vs. true values. From the following plot, you can see that the predicted and true values followed a similar pattern overall.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

plt.scatter(train_predictions, train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_labels, c='g', s=40, label='Test')
plt.title("Scatter plot of Fitted vs True values")
plt.ylabel("True values")
plt.xlabel("Fitted values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### Residual plot
#
# Every data point has a residual. It is the difference between the real value and the predicted value. Residuals are calculated like this:
# $e = y - \hat y$
#
# A positive residual means a higher prediction than true value, and a negative residual means a lower prediction than true value.
#
# Take a look at the residual plot from running the following block. There is a random pattern in residuals, which is good. Other patterns you might see are the U-shape or inverted U-shape patterns. These two patterns point out some non-linearity in the data, which needs to be fixed. In this case case, we don't have that problem.

# %%
import matplotlib.pyplot as plt
#%matplotlib inline

plt.scatter(train_predictions, train_predictions-train_labels, c='b', s=40, alpha=0.25, label='Training')
plt.scatter(test_predictions, test_predictions-test_labels, c='g', s=40, label='Test')
plt.hlines(y=0, xmin=0, xmax=300)
plt.title("Residual plots")
plt.ylabel("Residuals")
plt.xlabel("Fitted Values")
plt.legend(loc='best')
plt.show()

# %% [markdown]
# >### Question 3: Residual plot assessment
# >
# >In general, looking at a residual plot allows you to realize a pattern. Patterns include:
# >- Random: This means the data is linear.
# >- U or inverse U shape: This points out some non-linearity in the data.
# >
# >What can you conclude from the residual plot?

# %% [markdown]
# **Answer**: The plot shows random residuals, meaning the data is linear.

# %% [markdown]
# ## 4. Conclusion
# In this exercise, you developed a regression model using the linear learning algorithm in Amazon SageMaker. You also covered important concepts, such as training, validation, and test splits; the mean squared error regression metric; and analysis of residual error.
